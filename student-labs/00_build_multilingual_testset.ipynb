# %%
from datasets import load_dataset
from itertools import islice
import json
from datetime import datetime

# %%
import re
from nltk.tokenize import sent_tokenize
from tqdm import tqdm
from collections import defaultdict
from transformers import AutoTokenizer

# %%
langs = ["eng_Latn", "bul_Cyrl", "kor_Hang", "jpn_Jpan", "spa_Latn"]
samples = {}

def serialize_datetime(obj):
    if isinstance(obj, datetime):
        return obj.isoformat()
    raise TypeError(f"Type {type(obj)} not serializable")
    
for lang in langs:
    print(f"Loading samples from: {lang}")
    stream = load_dataset("HPLT/HPLT2.0_cleaned", lang, split="train", streaming=True)
    samples[lang] = list(islice(stream, 1500))


with open("test_data.jsonl", "w", encoding="utf-8") as f:
    for lang, items in samples.items():
        for item in items:
            item["lang_group"] = lang
            f.write(json.dumps(item, ensure_ascii=False, default=serialize_datetime) + "\n")

print("test_data.jsonl saved.")
# Out:
# Loading samples from: eng_Latn
# Resolving data files:   0%|          | 0/40367 [00:00<?, ?it/s]
# Loading samples from: bul_Cyrl
# Resolving data files:   0%|          | 0/386 [00:00<?, ?it/s]
# Loading samples from: kor_Hang
# Resolving data files:   0%|          | 0/464 [00:00<?, ?it/s]
# Loading samples from: jpn_Jpan
# Resolving data files:   0%|          | 0/5648 [00:00<?, ?it/s]
# Loading samples from: spa_Latn
# Resolving data files:   0%|          | 0/4687 [00:00<?, ?it/s]
# test_data.jsonl saved.

# %%
tokenizer = AutoTokenizer.from_pretrained("AllenAI/OLMoE-1B-7B-0924")

# %%
def extract_valid_sentence(text, min_len=5, max_len=50):
    sentences = re.split(r'[.!?。？！]\s*', text.strip())
    for sentence in sentences:
        sentence = sentence.strip()
        token_count = len(tokenizer.tokenize(sentence))
        if min_len <= len(sentence) <= max_len:
            return sentence
    return None

min_tokens = 10
max_tokens = 50
max_per_language = 1000

with open("test_data.jsonl", "r", encoding="utf-8") as f:
    raw_data = [json.loads(line) for line in f]

seen_texts = set()
language_counts = defaultdict(int)
filtered_data = []

for item in raw_data:
    lang = item["lang_group"]
    
    if language_counts[lang] >= max_per_language:
        continue

    sentence = extract_valid_sentence(item["text"], min_tokens, max_tokens)
    if sentence and sentence not in seen_texts:
        seen_texts.add(sentence)
        language_counts[lang] += 1
        filtered_data.append({"lang": lang, "text": sentence})

with open("test_data_cleaned.jsonl", "w", encoding="utf-8") as f:
    for item in filtered_data:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")

print(f"Saved {len(filtered_data)} filtered sentences")
for lang, count in language_counts.items():
    print(f"{lang}: {count}")
# Out:
# Saved 5000 filtered sentences
# eng_Latn: 1000
# bul_Cyrl: 1000
# kor_Hang: 1000
# jpn_Jpan: 1000
# spa_Latn: 1000
