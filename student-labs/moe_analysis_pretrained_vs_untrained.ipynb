# %% [markdown]
# # Untrained model routing patterns with a sample dataset

# %%
import torch
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer

MODEL_ID = "AllenAI/OLMoE-1B-7B-0924"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

# Load config only (no weights)
config = AutoConfig.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_config(config)  # On CPU
# Out:
# /usr/local/lib64/python3.12/site-packages/sklearn/utils/_param_validation.py:11: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.5)
#   from scipy.sparse import csr_matrix, issparse

# %% [markdown]
# ### problems with model configuration
#
# model = AutoModelForCausalLM.from_config(config)
#
# #### key limitations
# - no pre-trained weight
# - no quantization
# - no sharding
# - no fp16 computing
# - large model entirely in fp32 by default

# %% [markdown]
# ### torch.nn.DataParallel is not a solution
# #### problems
# -  model is first fully loaded onto cuda:0
# - remaining GPUs only used for gradient calculations (forward/backward)
# - model memory is *not* split
# => leads to OOM error
#
#
# -> solution here : use CPU
#  - Inference is slow
#  - But sufficient for checking routing behavior

# %%
model.eval()
# Out:
# OlmoeForCausalLM(
#   (model): OlmoeModel(
#     (embed_tokens): Embedding(50304, 2048, padding_idx=1)
#     (layers): ModuleList(
#       (0-15): 16 x OlmoeDecoderLayer(
#         (self_attn): OlmoeSdpaAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (q_norm): OlmoeRMSNorm((2048,), eps=1e-05)
#           (k_norm): OlmoeRMSNorm((2048,), eps=1e-05)
#         )
#         (mlp): OlmoeSparseMoeBlock(
#           (gate): Linear(in_features=2048, out_features=64, bias=False)
#           (experts): ModuleList(
#             (0-63): 64 x OlmoeMLP(
#               (gate_proj): Linear(in_features=2048, out_features=1024, bias=False)
#               (up_proj): Linear(in_features=2048, out_features=1024, bias=False)
#               (down_proj): Linear(in_features=1024, out_features=2048, bias=False)
#               (act_fn): SiLUActivation()
#             )
#           )
#         )
#         (input_layernorm): OlmoeRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): OlmoeRMSNorm((2048,), eps=1e-05)
#       )
#     )
#     (norm): OlmoeRMSNorm((2048,), eps=1e-05)
#     (rotary_emb): OlmoeRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=50304, bias=False)
# )

# %%
# Dictionary to store the router outputs
router_logs = {}

def get_router_hook(layer_name):
    def hook(module, inputs, outputs):
        if isinstance(outputs, tuple):
            val = outputs[1] 
        else:
            val = outputs
        
        if isinstance(val, torch.Tensor) and val.shape[-1] == 64:
            # Detach and move to CPU to save GPU memory
            router_logs[layer_name] = val.detach().float().cpu()
    return hook

for name, module in model.named_modules():
    if hasattr(module, "_forward_hooks"):
        module._forward_hooks.clear()

print("Attaching spy hooks...")
hook_count = 0
for name, module in model.named_modules():
    # We target the specific gate layer in the OLMoE architecture
    if name.endswith("mlp.gate"): 
        module.register_forward_hook(get_router_hook(name))
        hook_count += 1

print(f"Attached {hook_count} hooks (Expect 32 for this model).")
# Out:
# Attaching spy hooks...
# Attached 16 hooks (Expect 32 for this model).

# %%
import json
from collections import defaultdict, Counter
from tqdm import tqdm

# Load test dataset
from collections import defaultdict
lang_samples = defaultdict(list)

for item in test_data:
    lang = item["lang"]
    if len(lang_samples[lang]) < 30:
        lang_samples[lang].append(item)

sampled_test_data = sum(lang_samples.values(), [])

# %%
sampled_test_data
# Out:
# [{'lang': 'eng_Latn',
#   'text': '3189\nSociologist Steven Seidman, author of such books as Beyond the Closet and Romantic Longings, recently interviewed me about lesbian identities and the changing landscape of sexual politics'},
#  {'lang': 'eng_Latn',
#   'text': 'Starting a blog is a bit like keeping a diary, which I did for so many years–throughout my teens and twenties'},
#  {'lang': 'eng_Latn',
#   'text': '206d\nKristof criticized professors for fostering a culture that “glorifies arcane unintelligibility while disdaining impact and audience'},
#  {'lang': 'eng_Latn',
#   'text': 'f51\nKristof criticized professors for fostering a culture that “glorifies arcane unintelligibility while disdaining impact and audience'},
#  {'lang': 'eng_Latn',
#   'text': '3e9\nA Palestinian man whose face is covered with a kefeyya emblazoned with Arabic writing points his Kalashnikov at the viewer'},
#  {'lang': 'eng_Latn',
#   'text': 'Same-sex parents and their children must grapple with non-recognition in the eyes of the law'},
#  {'lang': 'eng_Latn',
#   'text': 'Margarethe von Trotta frames her new bio-pic, Hannah Arendt, around the philosopher’s coverage of the trial of Adolf Eichmann'},
#  {'lang': 'eng_Latn',
#   'text': 'Wright Mills once wrote about being at a party of sociology grad students at Columbia who were working on the PhDs'},
#  {'lang': 'eng_Latn',
#   'text': '3e9\nToday, we laborers in the groves of academia are pitted against one another in a quest for increased productivity'},
#  {'lang': 'eng_Latn',
#   'text': '3e9\nLast week, the man who washed my hair in a beauty parlor –he was perhaps 30– nonchalantly referred to the person he shares a home with as his “husband'},
#  {'lang': 'eng_Latn',
#   'text': '1c56\nThe other night I learned via a friend’s Facebook post that Bob Bellah had died'},
#  {'lang': 'eng_Latn',
#   'text': 'Online dating sites are clearly the matchmaking tool of choice in my social world'},
#  {'lang': 'eng_Latn',
#   'text': '”\nRecounting her visit to Yaffa Eliach’s monumental “Tower of Faces” exhibit at the Holocaust Memorial Museum in Washington, D'},
#  {'lang': 'eng_Latn',
#   'text': '3e9\nWe all endure suffering, and we all lose loved ones'},
#  {'lang': 'eng_Latn',
#   'text': '3e9\nBeing normal isn’t all that its cracked up to be'},
#  {'lang': 'eng_Latn',
#   'text': '36b3\nToday, we laborers in the groves of academia are pitted against one another in a quest for increased productivity'},
#  {'lang': 'eng_Latn',
#   'text': 'Our systems have detected unusual traffic from your computer network'},
#  {'lang': 'eng_Latn',
#   'text': 'For decades, it was a rare occurrence to see a curvy model on a catwalk at a major runway show during New York Fashion Week'},
#  {'lang': 'eng_Latn',
#   'text': 'Mona Abhari is headed to the Iowa State Capitol, in Des Moines, on Friday morning'},
#  {'lang': 'eng_Latn',
#   'text': 'The news comes after a tumultuous month between the two companies'},
#  {'lang': 'eng_Latn',
#   'text': '11 Best Lara Jean Looks From “To All The Boys: P'},
#  {'lang': 'eng_Latn',
#   'text': "Editor's note: The author of this piece is a member of Portland DSA, the main organization supporting Paige Kreisman's campaign"},
#  {'lang': 'eng_Latn',
#   'text': 'Ilhan Omar introduced the Homes For All Act, which calls for 8'},
#  {'lang': 'eng_Latn',
#   'text': 'This Photo of Kendall Jenner at the Fendi Show Will Make You Do a Double Take\nIt happened again'},
#  {'lang': 'eng_Latn',
#   'text': 'fendi\nKim Jones Joins Fendi as Artistic Director\nHe will also keep his position at Dior Men'},
#  {'lang': 'eng_Latn',
#   'text': 'No one does a fashion show quite like Moschino and its latest one is the perfect proof'},
#  {'lang': 'eng_Latn',
#   'text': "Camila Mendes has been tapped to star in Salvatore Ferragamo's new campaign alongside Debby Ryan, Dara Allen, Paloma Elsesser, Kiersey Clemons, and Olivia Sui"},
#  {'lang': 'eng_Latn',
#   'text': 'Jill Kortleve and Paloma Elsesser tonight became the first ever so-called “plus-size” models to walk a Fendi runway'},
#  {'lang': 'eng_Latn',
#   'text': 'The Best Street Style From Milan Fashion Week 2020\nWhat is it about Milan Fashion Week 2020 that brings out the quirky eccentric side of everyone'},
#  {'lang': 'eng_Latn',
#   'text': 'Not only has Mike Bloomberg spent a lot of money on buying TV airtime, the ads his team has made for him are generally really good'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Басейните на София са затворени за софиянци, общината ги подари\n22 Август 2007\nВече две години столичният обществен плаж „Мария Луиза“ (бивш „Република“) не работи'},
#  {'lang': 'bul_Cyrl',
#   'text': '-\nТогава целият народ се събра като един човек на площада, който беше пред Портата на водата и казаха на книжника Ездра да донесе книгата на Мойсеевия закон, който ГОСПОД беше заповядал на Израил'},
#  {'lang': 'bul_Cyrl', 'text': 'Всичко за "пилешко месо" от Rozali'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Блекбърн – Портсмут\nБлекбърн – Портсмут Премиер 17:00 Теоретично и двата отбора все още са до известна степен застрашени от изпадане, но на всички ни е ясно, че това едва ли ще се случи'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Овен и другите зодии\nОще по темата\nИзбрано\nА това знаеш ли'},
#  {'lang': 'bul_Cyrl', 'text': 'Няма намерени резултати'},
#  {'lang': 'bul_Cyrl',
#   'text': 'com\n- / Фирми\n- / Промишленост и енергетика\n- / Резултати\nЕнергоинвестмънт АД се ангажира да предостави на бизнеса достъпна електроенергия, персонализирани решения и превъзходно обслужване'},
#  {'lang': 'bul_Cyrl',
#   'text': 'От години нашата цел е да утвърдим българската вяра в родната земя,\nкоято може да бъде мощен извор на благополучие и успех, ако се\nстопанисва с любов,'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Основни алгоритми\nAuthor: ИнфоМан\nSource: http://infoman'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Мъжете си падат по кучки\n• 141 коментара • 4/5\nКаква е разликата между кучката и доброто момиче'},
#  {'lang': 'bul_Cyrl',
#   'text': ', Unknown от Tekken, Barbarian от Diablo и TMNT'},
#  {'lang': 'bul_Cyrl', 'text': 'Ако искате да сте от онези баби, които вдяват'},
#  {'lang': 'bul_Cyrl', 'text': '„Йеховае могъщ”, 3Царе 22:11I'},
#  {'lang': 'bul_Cyrl', 'text': 'Scitec Nutrition CHROMIUM PICOLINATE 100 TABS'},
#  {'lang': 'bul_Cyrl', 'text': 'Вторник, 29 Април 2014 18:43\nPlovdivNews'},
#  {'lang': 'bul_Cyrl', 'text': '„Пристанище Бургас” ЕАД издаде бр'},
#  {'lang': 'bul_Cyrl',
#   'text': 'С решение на Министерски съвет от понеделник държавата прехвърли безвъзмездно на община Симитли правото на собственост върху детската градина в село Черниче'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Губернаторство Южен Ливан\nДокато сте в Ливан, не пропускайте да посетите Провинция\nГубернаторство Южен Ливан'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Miłek DesignSzkolna, Warszawa\nДостъп за инвалидни колички:\nСнимки от това място:\nStreetview:OpenStreetMap\nМаркирането е погрешно'},
#  {'lang': 'bul_Cyrl',
#   'text': ', съобщиха от ”правл¤ващи¤ орган на програмата'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Въпроси и отговори от Министерство на труда и социалната политика 5\nВъпрос: Как следва да се изчисли обезщетението по чл'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Внасяне на осигурителни вноски върху неначислени възнаграждения на членовете на управителни и контролни съвети на кооперациите\nЙосиф Милошев – директор на дирекция „Правна” в НОИ\nВ сп'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Въпроси и отговори от Министерството на труда и социалната политика\nИзточник: http://www'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Подобни обяви в София:\nНаправи VIP\nПОДАРЪК ЗА ЖЕНА49'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Фиордите представляват дълги десетки километри заливи, които навлизат зигзагообразно дълбоко в сушата'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Осигурителни права на съпрузите на самоосигуряващи се лица\nПетя Малакова, главен експерт в дирекция “Трудово право\nВ бр'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Подобни обяви в София:\nНаправи VIP\nSPO BUYUK ANADOLU RESORT-ALL INCLUSIVE - 5 * 26'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Нов индустриален мобилен компютър от Motorola SolutionsНов индустриален мобилен компютър от среден клас пуска на пазара Motorola Solutions'},
#  {'lang': 'bul_Cyrl',
#   'text': 'bg / Последни\nБотуши, кофи и лопати отпътуваха от Варна за Мизия и Бяла Слатина 18:27/News'},
#  {'lang': 'bul_Cyrl',
#   'text': 'Тук ще откриете много модели телефони от висок клас, с много добра резолюция на дисплея , бързи процесори ,две сим карти, WiFi, GPS, напълно свободен софтуер, много добра камера'},
#  {'lang': 'kor_Hang',
#   'text': '그것은 바로 자폭이었다, 경서가 고개를 가로저었다, 이 여자는 대체 누구인가, C-SAC-2107 100%시험패스 공부자료조금은 괜찮을 거다, 천하에 그 조건에 맞는 사람이 수천 명은 될 거요, 초고는 초상화 아래 적힌 글을 읽어보려 했지만, 너무 어려운 글자들이라서 포기한다'},
#  {'lang': 'kor_Hang',
#   'text': '특히 육아기본수당을 10만원 인상, 50만원을 지급하며 보훈명예수당 신설 등 도민에 대한 각종 복지혜택을 늘린다'},
#  {'lang': 'kor_Hang',
#   'text': '27일(현지시간) 향후 금리인상 속도를 늦출 수 있다는 제롬 파월 미 연방준비제도(Fed·연준) 의장의 발언에 힘입어 뉴욕증시의 다우존스30 산업평균지수는 전장보다 436'},
#  {'lang': 'kor_Hang',
#   'text': '화천 출신의 명문대 재학생과 졸업생들이 고향 후배들을 위해 자신들의 입학 노하우를 솔직 담백하게 풀어냈다'},
#  {'lang': 'kor_Hang', 'text': '책소개\n지식을만드는지식의 ‘초판본 한국소설문학선집’ 가운데 하나'},
#  {'lang': 'kor_Hang', 'text': '베스트총 9종 (10권)이 검색되었습니다'},
#  {'lang': 'kor_Hang', 'text': 'Apache HTTP Server Version 2'},
#  {'lang': 'kor_Hang',
#   'text': '- 내돈주고 사고먹고\n- 2019/06/06 15:07\n-\nby 덕후\n사실 빈츠를 사면하나씩 까먹기에 바빠서초콜릿 위에 그려진 유럽풍 문양을 제대로 즐길 여유가 없다'},
#  {'lang': 'kor_Hang',
#   'text': '【부산=IBS중앙방송】윤한석기자= 부산 사하소방서, 자율소방대의 초기 대응능력 향상을 위한 합동 소방훈련 실시◆\n부산 사하소방서(서장 신현수)는 2019년 9월 26일 15시에 구평동에 위치한 (주)모든 과 부산탱크터미널(대량 위험물 옥외탱크저장소)에서 소방차량 12대 소방공무원 50여명 및 자율소방대원 120여명을 동원하여 합동 소방훈련을 실시했다'},
#  {'lang': 'kor_Hang',
#   'text': '-\n-\n#무료국비지원과정 AWS클라우드 아키텍처 설계 및 운영엔지니어 양성\nIT시스템과 클라우드의 결합으로 최신 트랜드에 맞는 교육을 하여 현업에 바로 투입할 수 있는 실무전문가를 양성할 수 있다'},
#  {'lang': 'kor_Hang',
#   'text': "30\n- 작성자\n- 관리자\n- 첨부\n-\n■ 산사세계유산등재추진위원회(위원장 자승스님)는 '산사,한국의 산지 승원'\n대상 7개 산사의 다양한 유산에 대한 조사 및 연구 결과물로 『학술총서』\n2종(무형유산, 도면, 사진집)을 발간하였습니다"},
#  {'lang': 'kor_Hang',
#   'text': '2016다248325 배당이의 (카) 파기환송\n[가등기담보 등에 관한 법률 제11조 단서 후문에 따른 법률효과]\n◇1'},
#  {'lang': 'kor_Hang', 'text': '“\n이 보고서는 식용유 요리 시장 에 대한 심층 분석을 제공합니다'},
#  {'lang': 'kor_Hang',
#   'text': '회사는 개인정보취급방침을 개정하는 경우 웹사이트 공지사항(또는 개별공지)을 통하여 공지할 것입니다'},
#  {'lang': 'kor_Hang',
#   'text': '모든 제품은 핸드메이드 방식으로 주문제작하기 때문에 결제 기준일로부터 3~7일 소요(토요일 및 공휴일 제외)\n지역에 따라 추가 운임비가 발생될 수 있습니다'},
#  {'lang': 'kor_Hang',
#   'text': '지난해 창사 후 처음으로 수주 1조원 시대 막을 열었던 대보건설이 올해는 더 큰 목표를 세웠다'},
#  {'lang': 'kor_Hang', 'text': '정의당 좌파 : 각자도생 실리주의로 위기 돌파 가능한가'},
#  {'lang': 'kor_Hang',
#   'text': 'SBS아카데미컴퓨터아트 통신비밀보호법, 전기통신사업법, 정보통신망 이용촉진 및 정보보호 등에 관한 법률 등 정보통신서비스제공자가 준수하여야 할 관련 법규상의 개인정보보호 규정을 준수하며, 관련 법령에 의거한 개인정보취급방침을 정하여 이용자 권익 보호에 최선을 다하고 있습니다'},
#  {'lang': 'kor_Hang',
#   'text': '비밀할인 쇼핑친구 UUU몰 반품 교환 안내\n반품·교환에 관한 일반적인 사항은 판매자 제시 사항보다 관계법령을 우선 합니다'},
#  {'lang': 'kor_Hang',
#   'text': '트리니티 힐스 마감\n- 채용형태\n- 전체\n- 최종학력\n- 학력제한없음\n- 경력\n- 전체\n- 모집인원\n- oo명\n- 근무지역\n- 경기\n- 급여조건\n- 면접후협의\n- 분야\n- 전체\n- 업종\n- 기타\n모집내용\n트리니티 힐스 전시지원 프로젝트의 작가를 공모합니다'},
#  {'lang': 'kor_Hang',
#   'text': '혼성 그룹 ‘코요태’ 김종민과 신지가 최근 화제를 모은 ‘결혼설’에 대해 직접 밝힌다'},
#  {'lang': 'kor_Hang',
#   'text': '며칠 전에 테슬라의 최고경영자인 일론 머스크가 자신의 트위터에 한국의 출산율을 언급하여 화제가 됐다'},
#  {'lang': 'kor_Hang', 'text': '능력검정시험이 실검에 올라 관심을 모으고 있다'},
#  {'lang': 'kor_Hang', 'text': '오는 17일에 취임 100일을 맞이하는 윤석열 대통령의 성적표가 나왔네'},
#  {'lang': 'kor_Hang', 'text': '서울출장안마 바닥이 단단하고 물이 있고 전체 과정이 조정되어 있습니다'},
#  {'lang': 'kor_Hang',
#   'text': '배송주기\n(최소주문수량 1개 이상 / 최대주문수량 0개 이하)사이즈 가이드\n수량을 선택해주세요'},
#  {'lang': 'kor_Hang',
#   'text': 'Domain\nVolume\n(html pages)\nLanguage Pairs\nPlatform\nDomain\nVolume\n(html pages)\nLanguage Pairs\nPlatform\n- 목적언어의 원어민에 의한 영문번역을 시행하였습니다'},
#  {'lang': 'kor_Hang',
#   'text': '안녕하세요~ ^^\n오늘도 옥수수(oksusu)앱에서 진행중인 이벤트를 소개해드릴까 하는데요 바로 영화 캡틴 판타스틱 시사회 이벤트입니다'},
#  {'lang': 'kor_Hang',
#   'text': '- TERMS OF US\n제1조(목적)\n이 약관은 주식회사 프리츠(전자상거래 사업자)가 운영하는 프리츠 사이버 몰(이하 “몰”이라 한다)에서 제공하는 인터넷 관련 서비스(이하 “서비스”라 한다)를 이용함에 있어 사이버 몰과 이용자의 권리․의무 및 책임사항을 규정함을 목적으로 합니다'},
#  {'lang': 'kor_Hang', 'text': '상세설명 이미지를 자유롭게 확대/축소하시려면 원본 보기에서 가능합니다'},
#  {'lang': 'jpn_Jpan', 'text': '離婚をしようと思いましたが、子ども達のことを考え、今は踏みとどまっています'},
#  {'lang': 'jpn_Jpan',
#   'text': '概して、規模の大きな会社は信頼して利用できるところが大多数であると言えますが、非大手の消費者金融系の業者は、データに乏しく実際の利用者もかなり少ないので、口コミは必要不可欠なものということになるのではないでしょうか'},
#  {'lang': 'jpn_Jpan',
#   'text': '包茎手術は男性にとって大切な部分にメスを入れることになるので、何の事前知識がないまま包茎手術を受けるのは危険であるといえます'},
#  {'lang': 'jpn_Jpan',
#   'text': '142a\n賃貸物件を売りたい、または借りたいと考えた場合、初心者だとどうしたら良いのかわからないことも多いでしょう'},
#  {'lang': 'jpn_Jpan',
#   'text': 'クリーンブースのメリットについて\nクリーンブース役割やメリットについて\nまずクリーンブースというのは、規格やクラスに分類されているクリーンルームに比べると、導入コストを削減するために設置されることが多いです'},
#  {'lang': 'jpn_Jpan',
#   'text': '日頃のご愛顧に感謝してスタンダードシングルを\n特別価格¥6,500(税込)~ご利用いただけるお得なプランです'},
#  {'lang': 'jpn_Jpan',
#   'text': 'ファームウェア ダウンロード\nダウンロードサービスのご利用について\nダウンロードサービスのご利用にあたりましていくつかの注意・制限事項がございます'},
#  {'lang': 'jpn_Jpan',
#   'text': '安全上のご注意 ダウンロード\n- ネットワーク機器\n- 無線LANアクセスポイント\n- 屋外対応タイプ\nダウンロードサービスのご利用について\n取扱説明書ダウンロードサービスのご利用にあたりましては、いくつかの注意・制限事項がございます'},
#  {'lang': 'jpn_Jpan',
#   'text': 'ご注意と保守について ダウンロード\n- ネットワーク機器\n- 無線LANアクセスポイント\n- 屋内設置タイプ\nダウンロードサービスのご利用について\n取扱説明書ダウンロードサービスのご利用にあたりましては、いくつかの注意・制限事項がございます'},
#  {'lang': 'jpn_Jpan',
#   'text': '20 JMHC東海(3)\n[社会貢献活動]\nクラブの結束が強まるのにともない、地域社会への貢献活動も始まった'},
#  {'lang': 'jpn_Jpan',
#   'text': '23 JMHC熊本(2)\n[吉田友三さん]\n中野会長を事務局長として支えているのが吉田友三(JA6CUN)さんである'},
#  {'lang': 'jpn_Jpan',
#   'text': '18 JMHC東海(1)\nJMHCの活動は中央集権的なものでなく、活動は各地方、各クラブ単位で自由に行われてきたことはしばしば指摘してきた'},
#  {'lang': 'jpn_Jpan',
#   'text': '19 JMHC東海(2)\nこのころ、JMHC東海とは別に、東海エリアに「JMHC岐阜」や「JMHC浜松」などの組織ができ始める'},
#  {'lang': 'jpn_Jpan',
#   'text': '13 モービルハム最盛期\n[第3回全国大会]\n次いで3回目の「全国大会」は、昭和44年(1969年)8月23、24日に石川県七尾市和倉温泉「加賀屋」で開かれた'},
#  {'lang': 'jpn_Jpan',
#   'text': '26 JMHC京都(2)\n[無線隊の装備編成]\n久貝さんの無線隊の装備について触れておく'},
#  {'lang': 'jpn_Jpan',
#   'text': '11 JMHC全国組織へ\n[モービルハムとの出会い]\n横瀬伸銅(株)の経営陣として仕事は多忙になっていたが、アマチュア無線とのかかわりを断ち切りたくなかった横瀬さんは、モービルを始める'},
#  {'lang': 'jpn_Jpan',
#   'text': '30 受川さんのハム人生(2)\n[石塚さんとの交流]\n初交信の相手である石塚さんとは「同じ調理師同士ということで、毎日のように交信した」という'},
#  {'lang': 'jpn_Jpan',
#   'text': '17 JMHC関西(4)\n[葭谷さんのラジオ少年時代]\nJMHC関西の会計担当として、寺田さんとともに活動していた葭谷さんは昭和11年生まれ'},
#  {'lang': 'jpn_Jpan',
#   'text': '28 JMHC能登\n[JMHC和倉大会]\nJMHC全国大会が京都で開かれた翌年の昭和44年(1969年)8月23日、24日に、石川県七尾市の和倉温泉「加賀屋」で、全国大会が開催され、その日に配布された案内状が残されていたことについてはすでに触れた'},
#  {'lang': 'jpn_Jpan',
#   'text': '24 JMHC熊本(3)\n[日赤熊本支部とつながる]\nJMHC熊本の会長職は、原田さんがJMHC九州連合の会長になったために、新田さんが引き継ぎ、次いで杉島さんへと移り、平成3年からは中野さんに引き継がれている'},
#  {'lang': 'jpn_Jpan',
#   'text': '14 JMHC関西(1)\n[モービルハム名簿の発行]\n全国組織が整備されるのにともない、全国のモービル会員の名簿の必要性が高まってきた'},
#  {'lang': 'jpn_Jpan',
#   'text': '21 JMHC長野・諏訪地区\n[モービルハムの集まり諏訪]\n毎年開催されているJMHC全国大会のうちいくつかの大会の出席者リストが残されている'},
#  {'lang': 'jpn_Jpan',
#   'text': '12 JMHC全国大会開催へ\n[メーカー製モービルハム機登場]\n昭和40年(1965年)になると、ポータブル機、モービル機の開発が活発になり、数多くのメーカーが登場する'},
#  {'lang': 'jpn_Jpan',
#   'text': '22 JMHC熊本(1)\n[JMHC熊本の発足]\n第6回全国大会が白樺湖で開かれた翌年、昭和47年(1972年)の大会は熊本市で開催された'},
#  {'lang': 'jpn_Jpan', 'text': '27 JMHC京都(3)\n久貝さんの戦時の思い出は続く'},
#  {'lang': 'jpn_Jpan', 'text': '29 受川さんのハム人生(1)\n[ラジオ青年に]\nラジオの自作は楽しかった'},
#  {'lang': 'jpn_Jpan',
#   'text': '25 JMHC京都(1)\n[JMHC京都の誕生]\nJMHC熊本が誕生した昭和42年に京都でもJMHC京都が発足している'},
#  {'lang': 'jpn_Jpan',
#   'text': '15 JMHC関西(2)\n寺田さんがラジオ作りの手ほどきを受けたのが、大阪の歌舞伎座で照明や電気配線を担当していた電気係の人からであった'},
#  {'lang': 'jpn_Jpan',
#   'text': '16 JMHC関西(3)\n[OECの活動]\nOECの活動ぶりが何度も新聞やテレビに紹介されたことは触れたが、そのいくつかを紹介する'},
#  {'lang': 'jpn_Jpan', 'text': 'はじめに\n電源は無線機を動かすためにも、実験のためにも必要なものです'}]

# %%
# Start inference loop
results = []

for idx, item in enumerate(tqdm(sampled_test_data)):
    langs = item["lang"]
    text = item["text"]
    
    if isinstance(langs, str):
        langs = [langs]
    
    router_logs.clear()  # Clear old logs

    # Tokenize (on CPU)
    inputs = tokenizer(text, return_tensors="pt")  # don't send to device

    with torch.no_grad():
        _ = model(**inputs)

    # Analyze a specific layer (14)
    target_layer = "model.layers.14.mlp.gate"
    
    if target_layer in router_logs:
        logits = router_logs[target_layer]  # shape: [seq_len, num_experts]
        expert_ids = logits.argmax(dim=-1).view(-1).tolist()  # Most chosen expert per token

        for token_idx, expert_id in enumerate(expert_ids):
            for lang in langs:
                results.append({
                    "lang": lang,
                    "sentence_id": idx,
                    "token_idx": token_idx,
                    "expert_id": expert_id
                })
        if (idx + 1) % 100 == 0:
            pd.DataFrame(results).to_csv("partial_results.csv", index=False)
            results.clear()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [2:36:08<00:00, 78.07s/it]

# %%
df = pd.read_csv("partial_results.csv")
lang_expert_counter = defaultdict(Counter)

for _, row in df.iterrows():
    lang = row["lang"]
    expert_id = row["expert_id"]
    lang_expert_counter[lang][expert_id] += 1

for lang, counter in lang_expert_counter.items():
    print(f"\nTop experts used in language: {lang}")
    for expert_id, count in counter.most_common(10):
        print(f"  Expert {expert_id}: {count} times")
# Out:
# Top experts used in language: eng_Latn
#   Expert 40: 126 times
#   Expert 2: 57 times
#   Expert 42: 47 times
#   Expert 14: 35 times
#   Expert 57: 31 times
#   Expert 22: 30 times
#   Expert 36: 30 times
#   Expert 12: 28 times
#   Expert 60: 27 times
#   Expert 18: 27 times
#
# Top experts used in language: bul_Cyrl
#   Expert 11: 190 times
#   Expert 42: 168 times
#   Expert 24: 131 times
#   Expert 2: 129 times
#   Expert 60: 106 times
#   Expert 28: 83 times
#   Expert 1: 82 times
#   Expert 4: 76 times
#   Expert 44: 62 times
#   Expert 6: 54 times
#
# Top experts used in language: kor_Hang
#   Expert 50: 494 times
#   Expert 11: 285 times
#   Expert 15: 263 times
#   Expert 31: 209 times
#   Expert 35: 209 times
#   Expert 33: 208 times
#   Expert 21: 207 times
#   Expert 42: 149 times
#   Expert 12: 129 times
#   Expert 28: 124 times
#
# Top experts used in language: jpn_Jpan
#   Expert 17: 117 times
#   Expert 2: 114 times
#   Expert 21: 106 times
#   Expert 49: 87 times
#   Expert 26: 73 times
#   Expert 6: 54 times
#   Expert 18: 39 times
#   Expert 3: 25 times
#   Expert 7: 24 times
#   Expert 60: 20 times

# %% [markdown]
# # Pre-trained model routing patterns with a sample dataset

# %%
from transformers import BitsAndBytesConfig

# Define the model (AllenAI OLMoE-1B-7B)
MODEL_ID = "AllenAI/OLMoE-1B-7B-0924"

# Configure 4-bit quantization to save memory
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4"
)

print(f"Loading {MODEL_ID}...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    quantization_config=quant_config,
    device_map="auto"
)
print(f"Success! Model loaded on {model.device}")
# Out:
# Loading AllenAI/OLMoE-1B-7B-0924...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Success! Model loaded on cuda:0

# %%
# Dictionary to store the router outputs
router_logs = {}

# Clear old hooks (if re-running)
for name, module in model.named_modules():
    if hasattr(module, "_forward_hooks"):
        module._forward_hooks.clear()

# Attach new hooks to the router layers
print("Attaching spy hooks...")
hook_count = 0
for name, module in model.named_modules():
    # We target the specific gate layer in the OLMoE architecture
    if name.endswith("mlp.gate"): 
        module.register_forward_hook(get_router_hook(name))
        hook_count += 1

print(f"Attached {hook_count} hooks (Expect 32 for this model).")
# Out:
# Attaching spy hooks...
# Attached 16 hooks (Expect 32 for this model).

# %%
from tqdm import tqdm
# language_expert count dictionary
language_expert_counts = defaultdict(Counter)

for item in tqdm(sampled_test_data, desc="Processing samples"):
    langs = item["lang"]
    text = item["text"]
    
    if isinstance(langs, str):
        langs = [langs]
        
    # Clear router logs before each inference
    router_logs.clear()

    # Run inference
    inputs = tokenizer(text, return_tensors="pt").to(model.device)
    with torch.no_grad():
        _ = model(**inputs)

    # Analyze a specific layer (14)
    target_layer = "model.layers.14.mlp.gate"
    
    if target_layer in router_logs:
        logits = router_logs[target_layer] # [Seq, Experts]
        expert_ids = logits.argmax(dim=-1).view(-1).tolist()  # Top Experts

        # Count expert selection for each language tag
        for lang in langs:
            language_expert_counts[lang].update(expert_ids)
# Out:
# Processing samples: 100%|█████████████████████████████████████████████████████████████| 120/120 [02:02<00:00,  1.02s/it]

# %%
for lang, counter in language_expert_counts.items():
    print(f"\nTop experts used in language: {lang}")
    for expert_id, count in counter.most_common(10):
        print(f"  Expert {expert_id}: {count} times")
# Out:
# Top experts used in language: eng_Latn
#   Expert 49: 65 times
#   Expert 19: 47 times
#   Expert 63: 37 times
#   Expert 60: 34 times
#   Expert 18: 32 times
#   Expert 35: 25 times
#   Expert 46: 24 times
#   Expert 55: 23 times
#   Expert 20: 23 times
#   Expert 47: 22 times
#
# Top experts used in language: bul_Cyrl
#   Expert 13: 1350 times
#   Expert 60: 32 times
#   Expert 47: 21 times
#   Expert 19: 21 times
#   Expert 52: 19 times
#   Expert 12: 19 times
#   Expert 27: 13 times
#   Expert 26: 12 times
#   Expert 1: 12 times
#   Expert 61: 10 times
#
# Top experts used in language: kor_Hang
#   Expert 13: 2580 times
#   Expert 19: 314 times
#   Expert 47: 203 times
#   Expert 34: 91 times
#   Expert 52: 73 times
#   Expert 61: 37 times
#   Expert 9: 35 times
#   Expert 60: 32 times
#   Expert 12: 22 times
#   Expert 39: 18 times
#
# Top experts used in language: jpn_Jpan
#   Expert 13: 937 times
#   Expert 24: 295 times
#   Expert 19: 228 times
#   Expert 36: 141 times
#   Expert 47: 132 times
#   Expert 34: 85 times
#   Expert 61: 79 times
#   Expert 52: 51 times
#   Expert 12: 48 times
#   Expert 11: 38 times
